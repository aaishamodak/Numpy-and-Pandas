# %%
import plotly
import pandas as pd
import numpy as np
import logging

# %%
import plotly.express as px

# %%
df = pd.read_csv('superstore.csv')

# %%
try:
    region_wise_df = df1.groupby(['Region']).size().rename('cnt').reset_index()
    logger.info("Successfully created .")
    print(region_wise_df)
except Exception as e:
    logger.error(f"Error")
# Out:
#     Region  cnt
# 0  Central    3
# 1    South    5
# 2     West   12

# %%
df1 = df.head(20)
df1
# Out:
#       no       order _id  Order Date   Ship Date       Ship Mode Customer ID  \
# 0    NaN             NaN  11-08-2016  11-11-2016    Second Class    CG-12520
# 1    2.0  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2    3.0  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3    4.0  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4    5.0  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 5    6.0  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 6    7.0  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 7    8.0  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 8    9.0  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 9   10.0  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 10  11.0  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# ...

# %%
df1.Region.value_counts()
# Out:
# Region
# West       12
# South       5
# Central     3
# Name: count, dtype: int64

# %%
try:
    fig = px.bar(df1, x='Region')
    fig.update_traces(dict(marker_line_width=0))
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.bar(df1, x='Region', color='Region')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    region_wise_df = df1.groupby(['Region']).size().rename('cnt').reset_index()
    logger.info("Successfully created .")
    print(region_wise_df)
except Exception as e:
    logger.error(f"Error: {e}")
# Out:
#     Region  cnt
# 0  Central    3
# 1    South    5
# 2     West   12

# %%
try:
    fig = px.bar(region_wise_df, x='Region', y='cnt', color='Region', text='cnt')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.bar(df1, x='Region', color='Region', color_discrete_sequence=['red', 'green', 'purple'])
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.bar(df1, x='Quantity', y='Profit')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.bar(df1, x='Quantity', y='Discount')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.bar(df1, x='Discount', y='Profit')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.bar(df1, x='Quantity', y='Profit', text='Quantity', color='Quantity')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.bar(df1, x='State', y='Sales', color='Category', title='Graph')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    subcategory_sales = df1.groupby('Sub-Category')['Sales'].sum().reset_index()
    fig = px.bar(subcategory_sales, x='Sub-Category', y='Sales', color='Sub-Category', title='Total Sales by Sub-Category')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.bar(df1, x='Category', y='Sales', color='State', pattern_shape_sequence=['x'])
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the bar chart: {e}")

# %%
try:
    fig = px.scatter(df1, x='Sales', y='Profit', color='Category', size='Quantity', hover_data=['Product Name'], title='Sales vs. Profit by Category')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the scatter plot: {e}")

# %%
try:
    fig = px.scatter(df1, x='Quantity', y='Profit', color='Discount', size='Quantity')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the scatter plot: {e}")

# %%
try:
    fig = px.scatter(df1, x='Quantity', y='Discount', color='Segment', facet_col='Ship Mode', facet_row='Region')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the scatter plot: {e}")

# %%
try:
    fig = px.scatter(df1, x='Sales', y='Profit', trendline='ols', title='Sales vs. Profit with Trendline')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the scatter plot: {e}")

# %%
try:
    fig = df1.groupby('Order Date')['Sales'].sum().reset_index()
    line_fig = px.line(fig, x='Order Date', y='Sales', title='Sales Trend Over Time')
    line_fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the line chart: {e}")

# %%
try:
    fig = px.line(df1, x='Order Date', y='Sales', color='Region', markers=True)
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the line chart: {e}")

# %%
try:
    hist_fig = px.histogram(df1, x='Discount', nbins=20, title='Distribution of Discounts', marginal='box')
    hist_fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the histogram: {e}")

# %%
try:
    fig10 = px.histogram(df1, x='Sales', color='Ship Mode')
    fig10.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the histogram: {e}")

# %%
try:
    fig12 = px.histogram(df1, x='Ship Mode', y='Sales', color='Ship Mode', pattern_shape='Quantity')
    fig12.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the histogram: {e}")

# %%
try:
    fig = px.box(df1, x='Region', y='Profit', color='Region', points='outliers')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the box plot: {e}")

# %%
try:
    fig = px.box(df1, x='Region', y='Profit', color='Region', title='Profit Distribution by Region', points='all')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the box plot: {e}")

# %%
try:
    fig = px.box(df1, x='Region', y='Profit', points='all', color='Category', notched=True, hover_data=['Sub-Category'], title='Profit Distribution Across Regions')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the box plot: {e}")

# %%
try:
    fig = px.strip(df1, x='Order Date', y='Sales')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the strip plot: {e}")

# %%
try:
    fig = px.violin(df1, y='Sales', box=True, points='all')
    fig.show()
    logger.info("Successfully created.")
except Exception as e:
    logger.error(f"Error while creating the violin plot: {e}")
